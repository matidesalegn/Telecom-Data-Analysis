# %% [markdown]
# # Task 1

# %% [markdown]
# ## Create a connection to the PostgreSQL database:

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import numpy as np
from IPython.display import Image
import seaborn as sns
import matplotlib.pyplot as plt

import os
import pandas as pd
os.chdir('..')
from DB_Connection.connection import PostgresConnection

# %% [markdown]
# ## Load the fetched data into a Pandas DataFrame:

# %%
import pandas as pd

# Import the PostgresConnection class from connection.py
from DB_Connection.connection import PostgresConnection

# Create an instance of the PostgresConnection class with your database credentials
db = PostgresConnection(dbname='telecom', user='postgres', password='Mati@1993')

# Connect to the PostgreSQL database
db.connect()

# create SQL queries
sql_query = """ SELECT * FROM public.xdr_data """

# Execute SQL query and load data into a Pandas DataFrame
df = pd.read_sql_query(sql_query, db.conn)

# Close the database connection
db.close_connection()

# Perform exploratory data analysis (EDA)
# Your EDA code goes here

# Print the first few rows of the DataFrame
df.head()
# Out:
# Connected to PostgreSQL database!
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\1783952959.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql_query, db.conn)
# Connection closed.
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Execute the SQL queries to fetch the data:

# %% [markdown]
# ### Write SQL queries to extract the relevant data from the dataset:

# %%
# Connect to the PostgreSQL database
db.connect()

# create SQL queries
sql_query = """ SELECT * FROM public.xdr_data """

# Execute SQL query and load data into a Pandas DataFrame
df = pd.read_sql_query(sql_query, db.conn)

# Close the database connection
db.close_connection()

# Perform exploratory data analysis (EDA)
# Your EDA code goes here

# Print the first few rows of the DataFrame
df.head()
# Out:
# Connected to PostgreSQL database!
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\3623058557.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql_query, db.conn)
# Connection closed.
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
# Display the DataFrame as a table
display(df)
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0       1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1       1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2       1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3       1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4       1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
# ...           ...           ...            ...           ...
# 149996    81230.0  2.082022e+14   3.365069e+10  3.548311e+13
# 149997    97970.0  2.082019e+14   3.366345e+10  3.566051e+13
# 149998    98249.0  2.082017e+14   3.362189e+10  3.572121e+13
# 149999    97910.0  2.082021e+14   3.361962e+10  8.618620e+13
# 150000        NaN           NaN            NaN           NaN
#
#            Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0       9.16456699548519E+015  ...        1.585461e+07        2.501332e+06
# 1                     L77566A  ...        2.024740e+07        1.911173e+07
# 2                     D42335A  ...        1.972566e+07        1.469958e+07
# 3                     T21824A  ...        2.138812e+07        1.514664e+07
# 4                     D88865A  ...        1.525938e+07        1.896287e+07
# ...                       ...  ...                 ...                 ...
# 149996                D20434A  ...        1.619167e+07        1.176343e+07
# 149997                D10223C  ...        1.387723e+07        8.288284e+06
# 149998                T51102A  ...        2.266051e+07        1.855903e+06
# 149999                L88342B  ...        8.817106e+06        8.305402e+06
# 150000                   None  ...        1.163407e+07        1.100941e+07
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0             8.198936e+06        9.656251e+06       2.780823e+08
# 1             1.833841e+07        1.722713e+07       6.087501e+08
# 2             1.758779e+07        6.163408e+06       2.295846e+08
# 3             1.399465e+07        1.097942e+06       7.995382e+08
# 4             1.712458e+07        4.152180e+05       5.277072e+08
# ...                    ...                 ...                ...
# 149996        1.788370e+07        1.967816e+07       5.266097e+08
# 149997        1.935015e+07        2.129315e+07       6.268931e+08
# 149998        9.963942e+06        5.065760e+06       5.535395e+08
# 149999        3.322253e+06        1.317259e+07       3.525370e+08
# 150000        1.162685e+07        1.100175e+07       4.220447e+08
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 0            1.434415e+07      1.717444e+08      8.814393e+06
# 1            1.170709e+06      5.269042e+08      1.505514e+07
# 2            3.956300e+05      4.106926e+08      4.215763e+06
# 3            1.084972e+07      7.490399e+08      1.279728e+07
# 4            3.529801e+06      5.507095e+08      1.391032e+07
# ...                   ...               ...               ...
# 149996       9.197207e+06      3.264510e+06      1.348742e+07
# 149997       4.735033e+06      7.121804e+08      2.457758e+06
# 149998       1.339432e+07      1.211009e+08      1.131473e+07
# 149999       2.529475e+06      8.147131e+08      1.406930e+06
# 150000       8.288398e+06      4.211005e+08      8.264799e+06
#
#         Total UL (Bytes)  Total DL (Bytes)
# 0             36749741.0       308879636.0
# 1             53800391.0       653384965.0
# 2             27883638.0       279807335.0
# 3             43324218.0       846028530.0
# 4             38542814.0       569138589.0
# ...                  ...               ...
# 149996        57628851.0       574175259.0
# 149997        39135081.0       666648844.0
# 149998        34912224.0       592786405.0
# 149999        29626096.0       371895920.0
# 150000               NaN               NaN
#
# [150001 rows x 55 columns]

# %%
df.columns.tolist()
# Out:
# ['Bearer Id',
#  'Start',
#  'Start ms',
#  'End',
#  'End ms',
#  'Dur. (ms)',
#  'IMSI',
#  'MSISDN/Number',
#  'IMEI',
#  'Last Location Name',
#  'Avg RTT DL (ms)',
#  'Avg RTT UL (ms)',
#  'Avg Bearer TP DL (kbps)',
#  'Avg Bearer TP UL (kbps)',
#  'TCP DL Retrans. Vol (Bytes)',
#  'TCP UL Retrans. Vol (Bytes)',
#  'DL TP < 50 Kbps (%)',
#  '50 Kbps < DL TP < 250 Kbps (%)',
#  '250 Kbps < DL TP < 1 Mbps (%)',
#  'DL TP > 1 Mbps (%)',
#  'UL TP < 10 Kbps (%)',
#  '10 Kbps < UL TP < 50 Kbps (%)',
#  '50 Kbps < UL TP < 300 Kbps (%)',
#  'UL TP > 300 Kbps (%)',
#  'HTTP DL (Bytes)',
#  'HTTP UL (Bytes)',
#  'Activity Duration DL (ms)',
#  'Activity Duration UL (ms)',
#  'Dur. (ms).1',
#  'Handset Manufacturer',
#  'Handset Type',
#  'Nb of sec with 125000B < Vol DL',
#  'Nb of sec with 1250B < Vol UL < 6250B',
#  'Nb of sec with 31250B < Vol DL < 125000B',
#  'Nb of sec with 37500B < Vol UL',
#  'Nb of sec with 6250B < Vol DL < 31250B',
#  'Nb of sec with 6250B < Vol UL < 37500B',
#  'Nb of sec with Vol DL < 6250B',
#  'Nb of sec with Vol UL < 1250B',
#  'Social Media DL (Bytes)',
#  'Social Media UL (Bytes)',
#  'Google DL (Bytes)',
#  'Google UL (Bytes)',
#  'Email DL (Bytes)',
#  'Email UL (Bytes)',
#  'Youtube DL (Bytes)',
#  'Youtube UL (Bytes)',
#  'Netflix DL (Bytes)',
#  'Netflix UL (Bytes)',
#  'Gaming DL (Bytes)',
#  'Gaming UL (Bytes)',
#  'Other DL (Bytes)',
#  'Other UL (Bytes)',
#  'Total UL (Bytes)',
#  'Total DL (Bytes)']

# %%
len(df.columns)
df.shape
# Out:
# (150001, 55)

# %%
print (f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 150001 rows and 55 columns

# %%
#Total count of missing values across all columns in pur dataframe
df.isnull().sum().sum()
# Out:
# 1031392

# %% [markdown]
# ### Determining which columns have missing values
# df.isna().sum()

# %% [markdown]
# Some columns are missing lots of values, so let as fix some values. In order to fill the data we need to know weather the data is symmetrial or sjewed to one side.

# %%
df.describe()
# Out:
#           Bearer Id       Start ms         End ms     Dur. (ms)          IMSI  \
# count  1.490100e+05  150000.000000  150000.000000  1.500000e+05  1.494310e+05
# mean   1.013887e+19     499.188200     498.800880  1.046086e+05  2.082016e+14
# std    2.893173e+18     288.611834     288.097653  8.103762e+04  2.148809e+10
# min    6.917538e+18       0.000000       0.000000  7.142000e+03  2.040471e+14
# 25%    7.349883e+18     250.000000     251.000000  5.744050e+04  2.082014e+14
# 50%    7.349883e+18     499.000000     500.000000  8.639900e+04  2.082015e+14
# 75%    1.304243e+19     749.000000     750.000000  1.324302e+05  2.082018e+14
# max    1.318654e+19     999.000000     999.000000  1.859336e+06  2.140743e+14
#
#        MSISDN/Number          IMEI  Avg RTT DL (ms)  Avg RTT UL (ms)  \
# count   1.489350e+05  1.494290e+05    122172.000000    122189.000000
# mean    4.188282e+10  4.847455e+13       109.795706        17.662883
# std     2.447443e+12  2.241637e+13       619.782739        84.793524
# min     3.360100e+10  4.400152e+11         0.000000         0.000000
# 25%     3.365130e+10  3.546071e+13        32.000000         2.000000
# 50%     3.366371e+10  3.572201e+13        45.000000         5.000000
# 75%     3.368349e+10  8.611970e+13        70.000000        15.000000
# max     8.823971e+14  9.900120e+13     96923.000000      7120.000000
#
#        Avg Bearer TP DL (kbps)  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# count            150000.000000  ...        1.500010e+05        1.500010e+05
# mean              13300.045927  ...        1.163407e+07        1.100941e+07
# std               23971.878541  ...        6.710569e+06        6.345423e+06
# min                   0.000000  ...        5.300000e+01        1.050000e+02
# 25%                  43.000000  ...        5.833501e+06        5.517965e+06
# 50%                  63.000000  ...        1.161602e+07        1.101345e+07
# 75%               19710.750000  ...        1.744852e+07        1.651556e+07
# max              378160.000000  ...        2.325910e+07        2.201196e+07
#
#        Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# count        1.500010e+05        1.500010e+05       1.500010e+05
# mean         1.162685e+07        1.100175e+07       4.220447e+08
# std          6.725218e+06        6.359490e+06       2.439675e+08
# min          4.200000e+01        3.500000e+01       2.516000e+03
# 25%          5.777156e+06        5.475981e+06       2.104733e+08
# 50%          1.164222e+07        1.099638e+07       4.234081e+08
# 75%          1.747048e+07        1.650727e+07       6.331742e+08
# max          2.325919e+07        2.201196e+07       8.434419e+08
#
#        Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# count       1.500010e+05      1.500010e+05      1.500010e+05
# mean        8.288398e+06      4.211005e+08      8.264799e+06
# std         4.782700e+06      2.432050e+08      4.769004e+06
# min         5.900000e+01      3.290000e+03      1.480000e+02
# 25%         4.128476e+06      2.101869e+08      4.145943e+06
# 50%         8.291208e+06      4.218030e+08      8.267071e+06
# 75%         1.243162e+07      6.316918e+08      1.238415e+07
# max         1.655879e+07      8.434425e+08      1.655882e+07
#
#        Total UL (Bytes)  Total DL (Bytes)
# count      1.500000e+05      1.500000e+05
# mean       4.112121e+07      4.546434e+08
# std        1.127639e+07      2.441429e+08
# min        2.866892e+06      7.114041e+06
# 25%        3.322201e+07      2.431068e+08
# 50%        4.114331e+07      4.558411e+08
# 75%        4.903424e+07      6.657055e+08
# max        7.833131e+07      9.029696e+08
#
# [8 rows x 50 columns]

# %%
def percent_missing(df):
    #calculate total numnber of cells in dataframe
    totalCells = np.product(df.shape)
    # Count number of missing values in each column
    missingCount = df.isnull().sum()
    #All missing Values from the data
    totalMissing = missingCount.sum()

    print("The telecom database contains", round(((totalMissing/totalCells) * 100),2), "%", 'missing values', )

percent_missing(df)
# Out:
# The telecom database contains 12.5 % missing values
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2714394397.py:11: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df)

# %% [markdown]
# 2,Handling the missinf Data

# %%
df.isna().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# 250 Kbps < DL TP < 1 Mbps (%)                  754
# DL TP > 1 Mbps (%)                             754
# UL TP < 10 Kbps (%)                            792
# 10 Kbps < UL TP < 50 Kbps (%)                  792
# 50 Kbps < UL TP < 300 Kbps (%)                 792
# UL TP > 300 Kbps (%)                           792
# HTTP DL (Bytes)                              81474
# HTTP UL (Bytes)                              81810
# Activity Duration DL (ms)                        1
# Activity Duration UL (ms)                        1
# Dur. (ms).1                                      1
# Handset Manufacturer                           572
# Handset Type                                   572
# Nb of sec with 125000B < Vol DL              97538
# Nb of sec with 1250B < Vol UL < 6250B        92894
# Nb of sec with 31250B < Vol DL < 125000B     93586
# Nb of sec with 37500B < Vol UL              130254
# Nb of sec with 6250B < Vol DL < 31250B       88317
# Nb of sec with 6250B < Vol UL < 37500B      111843
# Nb of sec with Vol DL < 6250B                  755
# Nb of sec with Vol UL < 1250B                  793
# Social Media DL (Bytes)                          0
# Social Media UL (Bytes)                          0
# Google DL (Bytes)                                0
# Google UL (Bytes)                                0
# Email DL (Bytes)                                 0
# Email UL (Bytes)                                 0
# Youtube DL (Bytes)                               0
# Youtube UL (Bytes)                               0
# Netflix DL (Bytes)                               0
# Netflix UL (Bytes)                               0
# Gaming DL (Bytes)                                0
# Gaming UL (Bytes)                                0
# Other DL (Bytes)                                 0
# Other UL (Bytes)                                 0
# Total UL (Bytes)                                 1
# Total DL (Bytes)                                 1
# dtype: int64

# %%
#The missing percentage from each of the columns
percent_missing(df['Nb of sec with 37500B < Vol UL'])
percent_missing(df['Nb of sec with 6250B < Vol UL < 37500B'])
percent_missing(df['Nb of sec with 1250B < Vol UL < 6250B'])
percent_missing(df['Nb of sec with 125000B < Vol DL'])
percent_missing(df['Nb of sec with 31250B < Vol DL < 125000B'])
percent_missing(df['Nb of sec with 6250B < Vol DL < 31250B'])
percent_missing(df['TCP DL Retrans. Vol (Bytes)'])
percent_missing(df['TCP UL Retrans. Vol (Bytes)'])
percent_missing(df['HTTP DL (Bytes)'])
percent_missing(df['HTTP UL (Bytes)'])
percent_missing(df['Bearer Id'])
# Out:
# The telecom database contains 86.84 % missing values
# The telecom database contains 74.56 % missing values
# The telecom database contains 61.93 % missing values
# The telecom database contains 65.02 % missing values
# The telecom database contains 62.39 % missing values
# The telecom database contains 58.88 % missing values
# The telecom database contains 58.76 % missing values
# The telecom database contains 64.43 % missing values
# The telecom database contains 54.32 % missing values
# The telecom database contains 54.54 % missing values
# The telecom database contains 0.66 % missing values
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:2: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['Nb of sec with 37500B < Vol UL'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:3: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['Nb of sec with 6250B < Vol UL < 37500B'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:4: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['Nb of sec with 1250B < Vol UL < 6250B'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:5: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['Nb of sec with 125000B < Vol DL'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:6: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['Nb of sec with 31250B < Vol DL < 125000B'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:7: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['Nb of sec with 6250B < Vol DL < 31250B'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:8: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['TCP DL Retrans. Vol (Bytes)'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:9: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['TCP UL Retrans. Vol (Bytes)'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:10: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['HTTP DL (Bytes)'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:11: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['HTTP UL (Bytes)'])
# C:\Users\matiwos.desalegn\AppData\Local\Temp\ipykernel_2856\2937573625.py:12: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   percent_missing(df['Bearer Id'])

# %%
#Cleaning the columns with high missing values
df_clean = df.drop(['Nb of sec with 37500B < Vol UL',
                    'Nb of sec with 6250B < Vol UL < 37500B','Nb of sec with 1250B < Vol UL < 6250B',
                    'Nb of sec with 125000B < Vol DL',
                    'Nb of sec with 31250B < Vol DL < 125000B',
                    'Nb of sec with 6250B < Vol DL < 31250B',
                   'TCP DL Retrans. Vol (Bytes)',
                    'TCP UL Retrans. Vol (Bytes)',
                    'HTTP DL (Bytes)',
                    'HTTP UL (Bytes)'], axis=1)
df_clean=df_clean.dropna(subset=['End'])
df_clean.shape
print (f"The shape of the dataframe after cleaning some data is {df_clean.shape}")
# Out:
# The shape of the dataframe after cleaning some data is (150000, 45)

# %% [markdown]
# Since Their are many columns with high number of Missing Data , the data cleaning method is preferable

# %%
df_clean.isna().sum()
# Out:
# Bearer Id                           990
# Start                                 0
# Start ms                              0
# End                                   0
# End ms                                0
# Dur. (ms)                             0
# IMSI                                569
# MSISDN/Number                      1065
# IMEI                                571
# Last Location Name                 1152
# Avg RTT DL (ms)                   27828
# Avg RTT UL (ms)                   27811
# Avg Bearer TP DL (kbps)               0
# Avg Bearer TP UL (kbps)               0
# DL TP < 50 Kbps (%)                 753
# 50 Kbps < DL TP < 250 Kbps (%)      753
# 250 Kbps < DL TP < 1 Mbps (%)       753
# DL TP > 1 Mbps (%)                  753
# UL TP < 10 Kbps (%)                 791
# 10 Kbps < UL TP < 50 Kbps (%)       791
# 50 Kbps < UL TP < 300 Kbps (%)      791
# UL TP > 300 Kbps (%)                791
# Activity Duration DL (ms)             0
# Activity Duration UL (ms)             0
# Dur. (ms).1                           0
# Handset Manufacturer                571
# Handset Type                        571
# Nb of sec with Vol DL < 6250B       754
# Nb of sec with Vol UL < 1250B       792
# Social Media DL (Bytes)               0
# Social Media UL (Bytes)               0
# Google DL (Bytes)                     0
# Google UL (Bytes)                     0
# Email DL (Bytes)                      0
# Email UL (Bytes)                      0
# Youtube DL (Bytes)                    0
# Youtube UL (Bytes)                    0
# Netflix DL (Bytes)                    0
# Netflix UL (Bytes)                    0
# Gaming DL (Bytes)                     0
# Gaming UL (Bytes)                     0
# Other DL (Bytes)                      0
# Other UL (Bytes)                      0
# Total UL (Bytes)                      0
# Total DL (Bytes)                      0
# dtype: int64

# %%
df_clean.sample(5)
# Out:
#            Bearer Id            Start  Start ms             End  End ms  \
# 147950  1.311448e+19   4/29/2019 7:03     404.0  4/30/2019 7:03   752.0
# 124429  7.349883e+18   4/28/2019 6:05     260.0  4/29/2019 6:55   352.0
# 105385  7.349883e+18  4/27/2019 10:23     419.0  4/29/2019 9:27   912.0
# 39414   7.277826e+18   4/25/2019 3:25     255.0  4/26/2019 3:25   314.0
# 82816   1.304243e+19  4/27/2019 10:06     596.0  4/28/2019 1:39   179.0
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 147950    86382.0  2.082014e+14   3.365904e+10  3.566791e+13
# 124429    89422.0  2.082010e+14   3.366463e+10  8.656890e+13
# 105385   169454.0  2.082010e+14   3.366294e+10  3.550891e+13
# 39414     86400.0  2.082017e+14   3.365871e+10  3.586081e+13
# 82816     55967.0  2.082010e+14   3.367273e+10  3.567621e+13
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 147950            T72231C  ...          14912948.0          12207950.0
# 124429            T85862C  ...          10416226.0           4354182.0
# 105385            L14949C  ...          10472048.0          15493313.0
# 39414             D15150B  ...          10168528.0           5247051.0
# 82816             T78078A  ...           8575243.0          17333639.0
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 147950          11636530.0            378011.0        106852799.0
# 124429          19731728.0           1981287.0         78181746.0
# 105385           2052056.0           3316994.0          7302197.0
# 39414             650952.0          20292269.0        818926844.0
# 82816             786341.0          11411784.0        107093776.0
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 147950         16379167.0       266602259.0        15781405.0
# 124429           729300.0       131004095.0         8320544.0
# 105385           869671.0       620779290.0         2408909.0
# 39414          14499736.0        55565168.0          668614.0
# 82816          14733926.0       326496428.0         4484214.0
#
#         Total UL (Bytes)  Total DL (Bytes)
# 147950        46734244.0       139629371.0
# 124429        18554270.0       114320931.0
# 105385        26563896.0        34517425.0
# 39414         44156636.0       835615715.0
# 82816         52581859.0       126988292.0
#
# [5 rows x 45 columns]

# %%
df_clean['Start'] = pd.to_datetime(df['Start'])
df_clean['End'] = pd.to_datetime(df['End'])

# %%
df_clean.isna().sum()
# Out:
# Bearer Id                           990
# Start                                 0
# Start ms                              0
# End                                   0
# End ms                                0
# Dur. (ms)                             0
# IMSI                                569
# MSISDN/Number                      1065
# IMEI                                571
# Last Location Name                 1152
# Avg RTT DL (ms)                   27828
# Avg RTT UL (ms)                   27811
# Avg Bearer TP DL (kbps)               0
# Avg Bearer TP UL (kbps)               0
# DL TP < 50 Kbps (%)                 753
# 50 Kbps < DL TP < 250 Kbps (%)      753
# 250 Kbps < DL TP < 1 Mbps (%)       753
# DL TP > 1 Mbps (%)                  753
# UL TP < 10 Kbps (%)                 791
# 10 Kbps < UL TP < 50 Kbps (%)       791
# 50 Kbps < UL TP < 300 Kbps (%)      791
# UL TP > 300 Kbps (%)                791
# Activity Duration DL (ms)             0
# Activity Duration UL (ms)             0
# Dur. (ms).1                           0
# Handset Manufacturer                571
# Handset Type                        571
# Nb of sec with Vol DL < 6250B       754
# Nb of sec with Vol UL < 1250B       792
# Social Media DL (Bytes)               0
# Social Media UL (Bytes)               0
# Google DL (Bytes)                     0
# Google UL (Bytes)                     0
# Email DL (Bytes)                      0
# Email UL (Bytes)                      0
# Youtube DL (Bytes)                    0
# Youtube UL (Bytes)                    0
# Netflix DL (Bytes)                    0
# Netflix UL (Bytes)                    0
# Gaming DL (Bytes)                     0
# Gaming UL (Bytes)                     0
# Other DL (Bytes)                      0
# Other UL (Bytes)                      0
# Total UL (Bytes)                      0
# Total DL (Bytes)                      0
# dtype: int64

# %%
df_clean.sample(5)
# Out:
#            Bearer Id               Start  Start ms                 End  \
# 107594  7.349883e+18 2019-04-27 13:27:00     121.0 2019-04-29 06:17:00
# 8610    1.304243e+19 2019-04-24 15:27:00     277.0 2019-04-25 00:43:00
# 18459   7.349883e+18 2019-04-24 19:42:00     909.0 2019-04-25 03:56:00
# 6119    7.349883e+18 2019-04-24 11:21:00     514.0 2019-04-25 03:49:00
# 3069    1.304243e+19 2019-04-24 03:25:00     151.0 2019-04-25 03:25:00
#
#         End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 107594   797.0   146976.0  2.082010e+14   3.376217e+10  3.529861e+13
# 8610     455.0    33339.0  2.082017e+14   3.366392e+10  3.528501e+13
# 18459    220.0    29633.0  2.082017e+14   3.366840e+10  3.583601e+13
# 6119     442.0    59257.0  2.082018e+14   3.366828e+10  3.586281e+13
# 3069     184.0    86400.0  2.082017e+14   3.366475e+10  8.637690e+13
#
#        Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 107594            D14160C  ...          17426316.0          18267108.0
# 8610              D92943B  ...           9070573.0           7766312.0
# 18459             D32101C  ...           2359451.0          17168009.0
# 6119              D10387A  ...          17833701.0          18430522.0
# 3069              L88775B  ...           1887636.0          10628351.0
#
#         Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 107594          16694799.0          16246359.0        193119844.0
# 8610            13834478.0          11924897.0        143161806.0
# 18459            6792440.0           9947306.0        284246474.0
# 6119            11821202.0           2057192.0        378498785.0
# 3069            16974435.0          14916800.0        433461989.0
#
#         Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  \
# 107594          4982963.0       613897751.0        14812690.0
# 8610            1974316.0       291807790.0        11757685.0
# 18459          13290376.0       802009863.0          370372.0
# 6119           11284725.0       752843349.0         8926153.0
# 3069           13856105.0       206808409.0         2784433.0
#
#         Total UL (Bytes)  Total DL (Bytes)
# 107594        57921599.0       241062013.0
# 8610          34195920.0       174696533.0
# 18459         44355256.0       311851541.0
# 6119          43803552.0       413225695.0
# 3069          44080987.0       456369497.0
#
# [5 rows x 45 columns]

# %%
df_clean.head()
# Out:
#       Bearer Id               Start  Start ms                 End  End ms  \
# 0  1.311448e+19 2019-04-04 12:01:00     770.0 2019-04-25 14:35:00   662.0
# 1  1.311448e+19 2019-04-09 13:04:00     235.0 2019-04-25 08:15:00   606.0
# 2  1.311448e+19 2019-04-09 17:42:00       1.0 2019-04-25 11:58:00   652.0
# 3  1.311448e+19 2019-04-10 00:31:00     486.0 2019-04-25 07:36:00   171.0
# 4  1.311448e+19 2019-04-12 20:10:00     565.0 2019-04-25 10:40:00   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 45 columns]

# %% [markdown]
# Lets as check the skewnes of the columns next

# %%
# Identify columns with non-numeric values
non_numeric_columns = df_clean.select_dtypes(exclude=['number']).columns

# Drop columns with non-numeric values or handle them appropriately
df_numeric = df_clean.drop(columns=non_numeric_columns)

# Calculate skewness for numeric columns
skewness = df_numeric.skew(axis=0)

# %% [markdown]
# Fix Missing Values for Normal and skewed data

# %%
missing_columns = ["Avg RTT DL (ms)",
                   "Avg RTT UL (ms)",
                   "DL TP < 50 Kbps (%)",
                   "50 Kbps < DL TP < 250 Kbps (%)",
                   "250 Kbps < DL TP < 1 Mbps (%)",
                   "DL TP > 1 Mbps (%)",
                   "UL TP < 10 Kbps (%)",
                   "10 Kbps < UL TP < 50 Kbps (%)",
                   "50 Kbps < UL TP < 300 Kbps (%)",
                   "UL TP > 300 Kbps (%)",
                   "Nb of sec with Vol DL < 6250B",
                   "Nb of sec with Vol UL < 1250B"]

# %%
def fix_missing_mean(df, col):
    df[col] = df[col].fillna(df[col].mean())
    return df[col]

def fix_missing_median(df, col):
    df[col] = df[col].fillna(df[col].median())
    return df[col]

def fix_missing_mode(df, col):
    df[col] = df[col].fillna(df_clean[col].mode()[0])
    return df[col]

# %%
for i in missing_columns:
    df_clean[i] = fix_missing_median(df_clean, i)
df_clean["Last Location Name"] = fix_missing_mode(df_clean,"Last Location Name")

# %%
df_clean.isna().sum()
# Out:
# Bearer Id                          990
# Start                                0
# Start ms                             0
# End                                  0
# End ms                               0
# Dur. (ms)                            0
# IMSI                               569
# MSISDN/Number                     1065
# IMEI                               571
# Last Location Name                   0
# Avg RTT DL (ms)                      0
# Avg RTT UL (ms)                      0
# Avg Bearer TP DL (kbps)              0
# Avg Bearer TP UL (kbps)              0
# DL TP < 50 Kbps (%)                  0
# 50 Kbps < DL TP < 250 Kbps (%)       0
# 250 Kbps < DL TP < 1 Mbps (%)        0
# DL TP > 1 Mbps (%)                   0
# UL TP < 10 Kbps (%)                  0
# 10 Kbps < UL TP < 50 Kbps (%)        0
# 50 Kbps < UL TP < 300 Kbps (%)       0
# UL TP > 300 Kbps (%)                 0
# Activity Duration DL (ms)            0
# Activity Duration UL (ms)            0
# Dur. (ms).1                          0
# Handset Manufacturer               571
# Handset Type                       571
# Nb of sec with Vol DL < 6250B        0
# Nb of sec with Vol UL < 1250B        0
# Social Media DL (Bytes)              0
# Social Media UL (Bytes)              0
# Google DL (Bytes)                    0
# Google UL (Bytes)                    0
# Email DL (Bytes)                     0
# Email UL (Bytes)                     0
# Youtube DL (Bytes)                   0
# Youtube UL (Bytes)                   0
# Netflix DL (Bytes)                   0
# Netflix UL (Bytes)                   0
# Gaming DL (Bytes)                    0
# Gaming UL (Bytes)                    0
# Other DL (Bytes)                     0
# Other UL (Bytes)                     0
# Total UL (Bytes)                     0
# Total DL (Bytes)                     0
# dtype: int64

# %%
df_clean['Bearer Id'].hist()
# Out:
# <Axes: >

# %%
df_clean['MSISDN/Number'].hist()
# Out:
# <Axes: >

# %%
df_clean['Total DL (Bytes)'].hist()
# Out:
# <Axes: >

# %%
df_clean['Social Media UL (Bytes)'].hist()
# Out:
# <Axes: >

# %% [markdown]
# In some columns their are still some Missing values

# %%
df_clean=df_clean.dropna(subset=['Bearer Id'])
df_clean=df_clean.dropna(subset=['MSISDN/Number'])
df_clean=df_clean.dropna(subset=['IMSI'])

# %%
df_clean.isna().sum()
# Out:
# Bearer Id                         0
# Start                             0
# Start ms                          0
# End                               0
# End ms                            0
# Dur. (ms)                         0
# IMSI                              0
# MSISDN/Number                     0
# IMEI                              0
# Last Location Name                0
# Avg RTT DL (ms)                   0
# Avg RTT UL (ms)                   0
# Avg Bearer TP DL (kbps)           0
# Avg Bearer TP UL (kbps)           0
# DL TP < 50 Kbps (%)               0
# 50 Kbps < DL TP < 250 Kbps (%)    0
# 250 Kbps < DL TP < 1 Mbps (%)     0
# DL TP > 1 Mbps (%)                0
# UL TP < 10 Kbps (%)               0
# 10 Kbps < UL TP < 50 Kbps (%)     0
# 50 Kbps < UL TP < 300 Kbps (%)    0
# UL TP > 300 Kbps (%)              0
# Activity Duration DL (ms)         0
# Activity Duration UL (ms)         0
# Dur. (ms).1                       0
# Handset Manufacturer              0
# Handset Type                      0
# Nb of sec with Vol DL < 6250B     0
# Nb of sec with Vol UL < 1250B     0
# Social Media DL (Bytes)           0
# Social Media UL (Bytes)           0
# Google DL (Bytes)                 0
# Google UL (Bytes)                 0
# Email DL (Bytes)                  0
# Email UL (Bytes)                  0
# Youtube DL (Bytes)                0
# Youtube UL (Bytes)                0
# Netflix DL (Bytes)                0
# Netflix UL (Bytes)                0
# Gaming DL (Bytes)                 0
# Gaming UL (Bytes)                 0
# Other DL (Bytes)                  0
# Other UL (Bytes)                  0
# Total UL (Bytes)                  0
# Total DL (Bytes)                  0
# dtype: int64

# %% [markdown]
# ## Task 1.1

# %% [markdown]
# ## User Overview analysis

# %% [markdown]
# ### Identify the top 10 handsets used by the customers:

# %%
top_10_handsets = df['Handset Type'].value_counts().head(10)

# %%
#top 10 handset used by customers
df['Handset Type'].value_counts()[0:10]
# Out:
# Handset Type
# Huawei B528S-23A                19752
# Apple iPhone 6S (A1688)          9419
# Apple iPhone 6 (A1586)           9023
# undefined                        8987
# Apple iPhone 7 (A1778)           6326
# Apple iPhone Se (A1723)          5187
# Apple iPhone 8 (A1905)           4993
# Apple iPhone Xr (A2105)          4568
# Samsung Galaxy S8 (Sm-G950F)     4520
# Apple iPhone X (A1901)           3813
# Name: count, dtype: int64

# %%
#top 3 handset manufacturers
df['Handset Manufacturer'].value_counts()[0:3]
# Out:
# Handset Manufacturer
# Apple      59565
# Samsung    40839
# Huawei     34423
# Name: count, dtype: int64

# %% [markdown]
# Let as choose a row Based on the top 3 Handset Manufacturer(column)

# %%
top_3_manufacturers = df['Handset Manufacturer'].value_counts().head(3)

# %%
df_top = df_clean.query('`Handset Manufacturer` in ["Apple", "Samsung", "Huawei"]')
len(df_top)
# Out:
# 134064

# %%
df_top_apple = df_clean.loc[df['Handset Manufacturer']=='Apple']
df_top_samsung = df_clean.loc[df['Handset Manufacturer']=='Samsung']
df_top_huawei = df_clean.loc[df['Handset Manufacturer']=='Huawei']

# %%
# Top 5 handset per top 3 handset manufacturer
df_top['Handset Type'].value_counts()[0:5]
# Out:
# Handset Type
# Huawei B528S-23A           19727
# Apple iPhone 6S (A1688)     9395
# Apple iPhone 6 (A1586)      8993
# Apple iPhone 7 (A1778)      6279
# Apple iPhone Se (A1723)     5165
# Name: count, dtype: int64

# %%
#Top 5 handset per the 1st Manufacturer
df_top_apple['Handset Type'].value_counts()[0:5]
# Out:
# Handset Type
# Apple iPhone 6S (A1688)    9395
# Apple iPhone 6 (A1586)     8993
# Apple iPhone 7 (A1778)     6279
# Apple iPhone Se (A1723)    5165
# Apple iPhone 8 (A1905)     4977
# Name: count, dtype: int64

# %%
#Top 5 handset per the 2nd Manufacturer
df_top_samsung['Handset Type'].value_counts()[0:5]
# Out:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4464
# Samsung Galaxy A5 Sm-A520F      3700
# Samsung Galaxy J5 (Sm-J530)     3675
# Samsung Galaxy J3 (Sm-J330)     3456
# Samsung Galaxy S7 (Sm-G930X)    3171
# Name: count, dtype: int64

# %%
#Top 5 handset per the 3rd Manufacturer
df_top_huawei['Handset Type'].value_counts()[0:5]
# Out:
# Handset Type
# Huawei B528S-23A                  19727
# Huawei E5180                       2074
# Huawei P20 Lite Huawei Nova 3E     2012
# Huawei P20                         1475
# Huawei Y6 2018                      996
# Name: count, dtype: int64

# %% [markdown]
# ### Identify the top 5 handsets per top 3 handset manufacturer:

# %%
for manufacturer in top_3_manufacturers.index:
    top_5_handsets = df[df['Handset Manufacturer'] == manufacturer]['Handset Type'].value_counts().head(5)
    print(f'Top 5 handsets for {manufacturer}:\n{top_5_handsets}\n')
# Out:
# Top 5 handsets for Apple:
# Handset Type
# Apple iPhone 6S (A1688)    9419
# Apple iPhone 6 (A1586)     9023
# Apple iPhone 7 (A1778)     6326
# Apple iPhone Se (A1723)    5187
# Apple iPhone 8 (A1905)     4993
# Name: count, dtype: int64
#
# Top 5 handsets for Samsung:
# Handset Type
# Samsung Galaxy S8 (Sm-G950F)    4520
# Samsung Galaxy A5 Sm-A520F      3724
# Samsung Galaxy J5 (Sm-J530)     3696
# Samsung Galaxy J3 (Sm-J330)     3484
# Samsung Galaxy S7 (Sm-G930X)    3199
# Name: count, dtype: int64
#
# Top 5 handsets for Huawei:
# Handset Type
# Huawei B528S-23A                  19752
# Huawei E5180                       2079
# Huawei P20 Lite Huawei Nova 3E     2021
# Huawei P20                         1480
# Huawei Y6 2018                      997
# Name: count, dtype: int64

# %% [markdown]
# Aggregating our Data per user Based on some columns used to track user Behaviour

# %%
user_behavior = df.groupby('MSISDN/Number').agg({'Bearer Id': 'count', 'Dur. (ms)': 'sum', 'Total UL (Bytes)': 'sum', 'Total DL (Bytes)': 'sum'})

# %%
Users = df_clean.groupby(['IMSI'])

xDR_users = df_clean['IMSI'].value_counts()
session_duration = Users['Dur. (ms)'].sum()
Total_session_UL = Users['Total UL (Bytes)'].sum()
Total_session_DL = Users['Total DL (Bytes)'].sum()
Total_Download_Social = Users['Social Media DL (Bytes)'].sum() + Users['Social Media UL (Bytes)'].sum()
Total_Download_Google = Users['Google DL (Bytes)'].sum() + Users['Google UL (Bytes)'].sum()
Total_Download_Email = Users['Email DL (Bytes)'].sum() + Users['Email UL (Bytes)'].sum()
Total_Download_Youtube = Users['Youtube DL (Bytes)'].sum() + Users['Youtube UL (Bytes)'].sum()
Total_Download_Netflix = Users['Netflix DL (Bytes)'].sum() + Users['Netflix UL (Bytes)'].sum()
Total_Download_Gaming = Users['Gaming DL (Bytes)'].sum() + Users['Gaming UL (Bytes)'].sum()
Total_Download_Other = Users['Other DL (Bytes)'].sum() + Users['Other DL (Bytes)'].sum()

# %%
# Print the column names of the DataFrame
print(df_norm.columns)
# Out:
# Index(['count', 'Dur. (ms)', 'Total UL (Bytes)', 'Total DL (Bytes)',
#        'Social media total volume (Bytes)', 'Google total volume (Bytes)',
#        'Email total volume (Bytes)', 'Youtube total volume (Bytes)',
#        'Netflix total volume (Bytes)', 'Gaming total volume (Bytes)',
#        'Other source total volume (Bytes)'],
#       dtype='object')

# %% [markdown]
# #### Calculate the total data volume (in Bytes) during this session for each application:

# %%
df['Social Media Data Volume'] = df['Social media total volume (Bytes)']
df['Google Data Volume'] = df['Google total volume (Bytes)']
df['Email Data Volume'] = df['Email total volume (Bytes)']
df['YouTube Data Volume'] = df['Youtube total volume (Bytes)']
df['Netflix Data Volume'] = df['Netflix total volume (Bytes)']
df['Gaming Data Volume'] = df['Gaming total volume (Bytes)']
df['Other Data Volume'] = df['Other source total volume (Bytes)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Week2\myenv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Social media total volume (Bytes)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 df['Social Media Data Volume'] = df['Social media total volume (Bytes)']
#       2 df['Google Data Volume'] = df['Google total volume (Bytes)']
#       3 df['Email Data Volume'] = df['Email total volume (Bytes)']
#
# File d:\Week2\myenv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File d:\Week2\myenv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Social media total volume (Bytes)'

# %% [markdown]
# Renaiming some columns to represent their Data (Total Volume)

# %%
new = pd.concat([xDR_users,
                 session_duration,
                 Total_session_UL,
                 Total_session_DL,
                 Total_Download_Social,
                 Total_Download_Google,
                 Total_Download_Email,
                 Total_Download_Youtube,
                 Total_Download_Netflix,
                 Total_Download_Gaming,
                 Total_Download_Other
                ], axis="columns", sort=True)

new = new.rename(columns={0: 'Social media total volume (Bytes)'})
new = new.rename(columns={1: 'Google total volume (Bytes)'})
new = new.rename(columns={2: 'Email total volume (Bytes)'})
new = new.rename(columns={3: 'Youtube total volume (Bytes)'})
new = new.rename(columns={4: 'Netflix total volume (Bytes)'})
new = new.rename(columns={5: 'Gaming total volume (Bytes)'})
new = new.rename(columns={'Other DL (Bytes)': 'Other source total volume (Bytes)'})
new = new.rename(columns={'IMSI': 'number of sessions'})

# %%
# Normalization will help to present a clwan visualization
df_norm = (new-new.min())/(new.max()-new.min())
df_norm.head(10)
# Out:
#                  count  Dur. (ms)  Total UL (Bytes)  Total DL (Bytes)  \
# IMSI
# 2.040471e+14  0.000000   0.046515          0.079246          0.008575
# 2.040808e+14  0.000000   0.046922          0.047377          0.022828
# 2.082001e+14  0.000000   0.004253          0.070080          0.002768
# 2.082001e+14  0.000000   0.004266          0.042268          0.047140
# 2.082001e+14  0.058824   0.030560          0.094203          0.116955
# 2.082001e+14  0.000000   0.000361          0.050014          0.080605
# 2.082001e+14  0.058824   0.019697          0.093479          0.107707
# 2.082001e+14  0.058824   0.012127          0.048915          0.117141
# 2.082001e+14  0.000000   0.004273          0.032029          0.051166
# 2.082001e+14  0.000000   0.006967          0.069117          0.037458
#
#               Social media total volume (Bytes)  Google total volume (Bytes)  \
# IMSI
# 2.040471e+14                           0.035610                     0.060324
# 2.040808e+14                           0.016454                     0.068342
# 2.082001e+14                           0.071962                     0.010413
# 2.082001e+14                           0.059381                     0.090509
# 2.082001e+14                           0.078969                     0.076408
# 2.082001e+14                           0.024215                     0.086986
# 2.082001e+14                           0.087286                     0.129537
# 2.082001e+14                           0.119686                     0.092172
# 2.082001e+14                           0.029163                     0.036969
# 2.082001e+14                           0.051235                     0.059382
#
#               Email total volume (Bytes)  Youtube total volume (Bytes)  \
# IMSI
# 2.040471e+14                    0.078131                      0.090227
# 2.040808e+14                    0.035438                      0.026234
# 2.082001e+14                    0.085832                      0.043728
# 2.082001e+14                    0.090507                      0.056480
# 2.082001e+14                    0.130807                      0.030386
# 2.082001e+14                    0.080676                      0.043097
# 2.082001e+14                    0.101640                      0.112234
# 2.082001e+14                    0.130263                      0.025933
# 2.082001e+14                    0.011457                      0.035840
# 2.082001e+14                    0.038388                      0.079064
#
#               Netflix total volume (Bytes)  Gaming total volume (Bytes)  \
# IMSI
# 2.040471e+14                      0.071774                     0.005519
# 2.040808e+14                      0.066129                     0.022937
# 2.082001e+14                      0.079247                     0.001138
# 2.082001e+14                      0.069118                     0.044366
# 2.082001e+14                      0.143135                     0.118385
# 2.082001e+14                      0.085123                     0.081614
# 2.082001e+14                      0.074368                     0.107743
# 2.082001e+14                      0.042228                     0.121213
# 2.082001e+14                      0.062830                     0.051615
# 2.082001e+14                      0.063633                     0.037385
#
#               Other source total volume (Bytes)
# IMSI
# 2.040471e+14                           0.048490
# 2.040808e+14                           0.058274
# 2.082001e+14                           0.062307
# 2.082001e+14                           0.037493
# 2.082001e+14                           0.131564
# 2.082001e+14                           0.068370
# 2.082001e+14                           0.058119
# 2.082001e+14                           0.132203
# 2.082001e+14                           0.099246
# 2.082001e+14                           0.043806

# %%
new1 = new.copy()
# Fix outlier function
def fix_outlier(df, column):
    df[column] = np.where(df[column] > df[column].quantile(0.95), df[column].median(),df[column])

    return df[column]
#fixing outliers for scaled table
for i in df_norm.columns.tolist():
    df_norm[i]=fix_outlier(df_norm,i)
#fixing outliers for non scaled table
for i in new.columns.tolist():
    new[i]=fix_outlier(new,i)
len(new)
# Out:
# 106470

# %% [markdown]
# # Univariate Analysis

# %%
# Print the column names of the DataFrame
print(df_norm.columns)
# Out:
# Index(['count', 'Dur. (ms)', 'Total UL (Bytes)', 'Total DL (Bytes)',
#        'Social media total volume (Bytes)', 'Google total volume (Bytes)',
#        'Email total volume (Bytes)', 'Youtube total volume (Bytes)',
#        'Netflix total volume (Bytes)', 'Gaming total volume (Bytes)',
#        'Other source total volume (Bytes)'],
#       dtype='object')

# %%
# univariate plots for Number of session and duration of XDR
fig, ax = plt.subplots(1, 2, figsize=(20, 6))
sns.histplot(df_norm['count'], ax=ax[0])
ax[0].set_title("Number of Sessions")
sns.histplot(df_norm['Dur. (ms)'], ax=ax[1])
ax[1].set_title("Duration (ms)")
plt.ylim(0, 2500)
# Out:
# (0.0, 2500.0)

# %%
# univariate plots fot Total UL & DL Bytes
fig, ax=plt.subplots(1,2, figsize=(20, 6))
sns.histplot(df_norm['Total UL (Bytes)'], ax=ax[0])
ax[0].set_title("Total UL (Bytes)")
sns.histplot(df_norm['Total DL (Bytes)'], ax=ax[1])
ax[1].set_title("Total DL (Bytes)")
# Out:
# Text(0.5, 1.0, 'Total DL (Bytes)')

# %%
# univariate plots for Netflix and Gaming total volume
fig, ax=plt.subplots(1,2, figsize=(20, 6))
sns.histplot(new['Netflix total volume (Bytes)'], ax=ax[0])
ax[0].set_title("Netflix total volume (Bytes)")
sns.histplot(new['Gaming total volume (Bytes)'], ax=ax[1])
ax[1].set_title("Gaming total volume (Bytes)")
plt.ylim(0, 2500)
# Out:
# (0.0, 2500.0)

# %%
# univariate plots fot other source total volume
fig, ax=plt.subplots(1, figsize=(9, 6))
sns.histplot(new['Other source total volume (Bytes)'])
ax.set_title("Other source total volume")
plt.ylim(0, 2500)
# Out:
# (0.0, 2500.0)

# %% [markdown]
# Bivariate Analysis

# %%
# Analysis between each application and total DL + UL Data
new['Total_DL_UL'] = new['Total DL (Bytes)'] + new['Total UL (Bytes)']

# %%
a4_dims = (20, 7)
fig, axs = plt.subplots(ncols=6,figsize=a4_dims)
sns.scatterplot(x="Social media total volume (Bytes)", y="Total_DL_UL",ax=axs[0], data=new)
sns.scatterplot(x="Gaming total volume (Bytes)", y="Total_DL_UL", ax=axs[1],data=new)
sns.scatterplot(x="Email total volume (Bytes)", y="Total_DL_UL",ax=axs[2], data=new)
sns.scatterplot(x="Youtube total volume (Bytes)", y="Total_DL_UL",ax=axs[3], data=new)
sns.scatterplot(x="Google total volume (Bytes)", y="Total_DL_UL",ax=axs[4], data=new)
sns.scatterplot(x="Other source total volume (Bytes)", y="Total_DL_UL",ax=axs[5], data=new)
plt.show()

# %% [markdown]
# # Variable Transformation

# %%
#Segment the users in to 5 classes baded on total duration
new['decile'] = pd.qcut(new['Dur. (ms)'], 5, labels =False, )
new.head(10)
# Out:
#               count  Dur. (ms)  Total UL (Bytes)  Total DL (Bytes)  \
# IMSI
# 2.040471e+14    1.0   103137.5        60456049.0        78697597.0
# 2.040808e+14    1.0   103137.5        37295915.0       194828056.0
# 2.082001e+14    1.0    86019.0        53794658.0        31376981.0
# 2.082001e+14    1.0    86254.0        33583272.0       392918313.0
# 2.082001e+14    2.0   103137.5        71325004.0       961767023.0
# 2.082001e+14    1.0    13835.0        39212281.0       665593389.0
# 2.082001e+14    2.0   103137.5        70799015.0       886414496.0
# 2.082001e+14    2.0   232058.0        38413689.0       963285344.0
# 2.082001e+14    1.0    86399.0        26142870.0       425721468.0
# 2.082001e+14    1.0   136356.0        53095277.0       314032149.0
#
#               Social media total volume (Bytes)  Google total volume (Bytes)  \
# IMSI
# 2.040471e+14                          1546088.0                    9218647.0
# 2.040808e+14                           715224.0                   10438660.0
# 2.082001e+14                          3122781.0                    1624662.0
# 2.082001e+14                          2577104.0                   13811478.0
# 2.082001e+14                          3426716.0                   11665887.0
# 2.082001e+14                          1051833.0                   13275341.0
# 2.082001e+14                          3787423.0                   19749603.0
# 2.082001e+14                          5192710.0                   14064424.0
# 2.082001e+14                          1266474.0                    5665229.0
# 2.082001e+14                          2223777.0                    9075463.0
#
#               Email total volume (Bytes)  Youtube total volume (Bytes)  \
# IMSI
# 2.040471e+14                   3330974.0                    40940710.0
# 2.040808e+14                   1520771.0                    11959905.0
# 2.082001e+14                   3657501.0                    19882439.0
# 2.082001e+14                   3855734.0                    25657632.0
# 2.082001e+14                   5564462.0                    13840201.0
# 2.082001e+14                   3438893.0                    19596808.0
# 2.082001e+14                   4327786.0                    50907243.0
# 2.082001e+14                   5541425.0                    11823461.0
# 2.082001e+14                    503950.0                    16310061.0
# 2.082001e+14                   1645862.0                    35885492.0
#
#               Netflix total volume (Bytes)  Gaming total volume (Bytes)  \
# IMSI
# 2.040471e+14                    28846230.0                   43070260.0
# 2.040808e+14                    26592300.0                  178048738.0
# 2.082001e+14                    31830562.0                    9124516.0
# 2.082001e+14                    27785852.0                  344105897.0
# 2.082001e+14                    57343415.0                  917684766.0
# 2.082001e+14                    34177184.0                  632745679.0
# 2.082001e+14                    29882137.0                  835218898.0
# 2.082001e+14                    17047546.0                  939598732.0
# 2.082001e+14                    25274811.0                  400273809.0
# 2.082001e+14                    25595503.0                  290007171.0
#
#               Other source total volume (Bytes)   Total_DL_UL  decile
# IMSI
# 2.040471e+14                       7.783194e+08  1.391536e+08       2
# 2.040808e+14                       9.353562e+08  2.321240e+08       2
# 2.082001e+14                       1.000089e+09  8.517164e+07       1
# 2.082001e+14                       6.018057e+08  4.265016e+08       1
# 2.082001e+14                       2.111738e+09  1.033092e+09       2
# 2.082001e+14                       1.097405e+09  7.048057e+08       0
# 2.082001e+14                       9.328757e+08  9.572135e+08       2
# 2.082001e+14                       2.121998e+09  1.001699e+09       4
# 2.082001e+14                       1.592992e+09  4.518643e+08       1
# 2.082001e+14                       7.031386e+08  3.671274e+08       3

# %%
#compute the total data (DL + UL) per Declie class
data_per_decile = new.groupby(['decile']).agg({'Total_DL_UL':['sum']})
data_per_decile.columns = ["_".join(x) for x in data_per_decile.columns.ravel()]

data_per_decile.head(10)
# Out:
#         Total_DL_UL_sum
# decile
# 0          1.143200e+13
# 1          1.226119e+13
# 2          1.264968e+13
# 3          1.290748e+13
# 4          1.609872e+13

# %%
#correlation Analaysis
df_new=df_norm[['Social media total volume (Bytes)',
                'Google total volume (Bytes)',
                'Email total volume (Bytes)',
                'Youtube total volume (Bytes)',
                'Netflix total volume (Bytes)',
                'Gaming total volume (Bytes)',
                'Other source total volume (Bytes)']]


corrMatrix = df_new.corr()
f, ax = plt.subplots(figsize=(13, 9))
sns.heatmap(corrMatrix,annot=True,fmt='.3f',annot_kws={"size":12})
plt.show()

# %%
new.index.name = 'customer ID'
new.reset_index(inplace=True)

new.head()
# Out:
#     customer ID  count  Dur. (ms)  Total UL (Bytes)  Total DL (Bytes)  \
# 0  2.040471e+14    1.0   103137.5        60456049.0        78697597.0
# 1  2.040808e+14    1.0   103137.5        37295915.0       194828056.0
# 2  2.082001e+14    1.0    86019.0        53794658.0        31376981.0
# 3  2.082001e+14    1.0    86254.0        33583272.0       392918313.0
# 4  2.082001e+14    2.0   103137.5        71325004.0       961767023.0
#
#    Social media total volume (Bytes)  Google total volume (Bytes)  \
# 0                          1546088.0                    9218647.0
# 1                           715224.0                   10438660.0
# 2                          3122781.0                    1624662.0
# 3                          2577104.0                   13811478.0
# 4                          3426716.0                   11665887.0
#
#    Email total volume (Bytes)  Youtube total volume (Bytes)  \
# 0                   3330974.0                    40940710.0
# 1                   1520771.0                    11959905.0
# 2                   3657501.0                    19882439.0
# 3                   3855734.0                    25657632.0
# 4                   5564462.0                    13840201.0
#
#    Netflix total volume (Bytes)  Gaming total volume (Bytes)  \
# 0                    28846230.0                   43070260.0
# 1                    26592300.0                  178048738.0
# 2                    31830562.0                    9124516.0
# 3                    27785852.0                  344105897.0
# 4                    57343415.0                  917684766.0
#
#    Other source total volume (Bytes)   Total_DL_UL  decile
# 0                       7.783194e+08  1.391536e+08       2
# 1                       9.353562e+08  2.321240e+08       2
# 2                       1.000089e+09  8.517164e+07       1
# 3                       6.018057e+08  4.265016e+08       1
# 4                       2.111738e+09  1.033092e+09       2

# %%
# Check the column names in the DataFrame
print(new.columns)
# Out:
# Index(['customer ID', 'count', 'Dur. (ms)', 'Total UL (Bytes)',
#        'Total DL (Bytes)', 'Social media total volume (Bytes)',
#        'Google total volume (Bytes)', 'Email total volume (Bytes)',
#        'Youtube total volume (Bytes)', 'Netflix total volume (Bytes)',
#        'Gaming total volume (Bytes)', 'Other source total volume (Bytes)',
#        'Total_DL_UL', 'decile'],
#       dtype='object')

# %%
# Sort the DataFrame by the 'count' column and select 'customer ID' and 'count' columns
new.sort_values(by='count', ascending=False)[['customer ID','count']]
# Out:
#          customer ID  count
# 25674   2.082010e+14    3.0
# 91287   2.082019e+14    3.0
# 80924   2.082018e+14    3.0
# 33491   2.082014e+14    3.0
# 84833   2.082019e+14    3.0
# ...              ...    ...
# 40240   2.082014e+14    1.0
# 40239   2.082014e+14    1.0
# 40238   2.082014e+14    1.0
# 40237   2.082014e+14    1.0
# 106469  2.082522e+14    1.0
#
# [106470 rows x 2 columns]

# %%
#Top 10 customer ID with session duration
new.sort_values(by='Dur. (ms)', ascending=False)[['customer ID','Dur. (ms)']].head(10)
# Out:
#          customer ID  Dur. (ms)
# 41879   2.082014e+14   370201.0
# 106403  2.082099e+14   370148.0
# 84612   2.082019e+14   370093.0
# 89297   2.082019e+14   370070.0
# 95236   2.082019e+14   370043.0
# 13954   2.082010e+14   369983.0
# 53579   2.082015e+14   369966.0
# 11974   2.082009e+14   369945.0
# 18121   2.082010e+14   369919.0
# 6466    2.082003e+14   369916.0

# %%
#Top 10 customer ID with total traffic
new.sort_values(by='Total_DL_UL', ascending=False)[['customer ID','Total_DL_UL']].head(10)
# Out:
#          customer ID   Total_DL_UL
# 89062   2.082019e+14  1.616057e+09
# 9286    2.082009e+14  1.610289e+09
# 46101   2.082015e+14  1.608583e+09
# 32470   2.082014e+14  1.608481e+09
# 46014   2.082015e+14  1.607649e+09
# 82305   2.082018e+14  1.607064e+09
# 106250  2.082099e+14  1.606917e+09
# 83165   2.082018e+14  1.606825e+09
# 27494   2.082014e+14  1.606420e+09
# 74160   2.082017e+14  1.604670e+09

# %% [markdown]
# Machine Learning Model

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
# scaled inorder to be suited for k- modeling
df_model = new[['customer ID', 'Dur. (ms)', 'Total_DL_UL', 'count']]
df_scaled = df_model.copy()
df_scaled[['Dur. (ms)', 'Total_DL_UL', 'count']] = (df_scaled[['Dur. (ms)', 'Total_DL_UL', 'count']] - df_scaled[['Dur. (ms)', 'Total_DL_UL', 'count']].min()) / (df_scaled[['Dur. (ms)', 'Total_DL_UL', 'count']].max() - df_scaled[['Dur. (ms)', 'Total_DL_UL', 'count']].min())
df_scaled.head(10)
# Out:
#     customer ID  Dur. (ms)  Total_DL_UL  count
# 0  2.040471e+14   0.264407     0.066909    0.0
# 1  2.040808e+14   0.264407     0.125647    0.0
# 2  2.082001e+14   0.217257     0.032804    0.0
# 3  2.082001e+14   0.217904     0.248453    0.0
# 4  2.082001e+14   0.264407     0.631690    0.5
# 5  2.082001e+14   0.018435     0.424282    0.0
# 6  2.082001e+14   0.264407     0.583750    0.5
# 7  2.082001e+14   0.619503     0.611856    0.5
# 8  2.082001e+14   0.218303     0.264476    0.0
# 9  2.082001e+14   0.355904     0.210941    0.0

# %%
import os
os.environ["LOKY_MAX_CPU_COUNT"] = "auto"

#classifying costomers in 3 group of engagments
kmeans = KMeans(n_clusters=3, random_state=0)
df_scaled['cluster'] = kmeans.fit_predict(df_scaled[['count', 'Dur. (ms)','Total_DL_UL']])

df_eng = df_scaled.copy()
df_scaled.head()
centroids = kmeans.cluster_centers_
cen_x = [i[0] for i in centroids]
cen_y = [i[1] for i in centroids]
## add to df
df_scaled['cen_x'] = df_scaled['cluster'].map({0:cen_x[0], 1:cen_x[1], 2:cen_x[2]})

df_scaled['cen_y'] = df_scaled['cluster'].map({0:cen_y[0], 1:cen_y[1], 2:cen_y[2]})
df_scaled.groupby(['cluster']).describe().transpose()
# Out:
# cluster                       0             1             2
# customer ID count  5.777800e+04  2.572700e+04  2.296500e+04
#             mean   2.082015e+14  2.082016e+14  2.082017e+14
#             std    2.437948e+10  1.323529e+09  1.517243e+09
#             min    2.040471e+14  2.082001e+14  2.082001e+14
#             25%    2.082010e+14  2.082014e+14  2.082010e+14
#             50%    2.082015e+14  2.082015e+14  2.082015e+14
#             75%    2.082018e+14  2.082018e+14  2.082018e+14
#             max    2.082522e+14  2.082099e+14  2.082099e+14
# Dur. (ms)   count  5.777800e+04  2.572700e+04  2.296500e+04
#             mean   1.753334e-01  4.527266e-01  4.933401e-01
#             std    9.054517e-02  2.342014e-01  1.554952e-01
#             min    0.000000e+00  3.055426e-02  3.251372e-01
#             25%    8.462536e-02  2.644074e-01  3.857252e-01
#             50%    2.182111e-01  4.562785e-01  4.405455e-01
#             75%    2.379441e-01  6.326424e-01  5.505854e-01
#             max    3.450293e-01  1.000000e+00  9.995648e-01
# Total_DL_UL count  5.777800e+04  2.572700e+04  2.296500e+04
#             mean   2.955643e-01  5.796317e-01  3.074663e-01
#             std    1.562743e-01  2.025269e-01  1.606253e-01
#             min    0.000000e+00  5.466206e-02  2.064881e-04
#             25%    1.625577e-01  4.065629e-01  1.729860e-01
#             50%    2.999240e-01  5.783280e-01  3.168226e-01
#             75%    4.209643e-01  7.387910e-01  4.332068e-01
#             max    9.854428e-01  1.000000e+00  9.719432e-01
# count       count  5.777800e+04  2.572700e+04  2.296500e+04
#             mean   9.605732e-04  5.858631e-01  0.000000e+00
#             std    2.189457e-02  1.885748e-01  0.000000e+00
#             min    0.000000e+00  5.000000e-01  0.000000e+00
#             25%    0.000000e+00  5.000000e-01  0.000000e+00
#             50%    0.000000e+00  5.000000e-01  0.000000e+00
#             75%    0.000000e+00  5.000000e-01  0.000000e+00
#             max    5.000000e-01  1.000000e+00  0.000000e+00
# cen_x       count  5.777800e+04  2.572700e+04  2.296500e+04
#             mean   9.585161e-04  5.858631e-01  8.104628e-15
#             std    0.000000e+00  1.110245e-16  0.000000e+00
#             min    9.585161e-04  5.858631e-01  8.104628e-15
#             25%    9.585161e-04  5.858631e-01  8.104628e-15
#             50%    9.585161e-04  5.858631e-01  8.104628e-15
#             75%    9.585161e-04  5.858631e-01  8.104628e-15
#             max    9.585161e-04  5.858631e-01  8.104628e-15
# cen_y       count  5.777800e+04  2.572700e+04  2.296500e+04
#             mean   1.756806e-01  4.527266e-01  4.941866e-01
#             std    2.775582e-17  1.110245e-16  0.000000e+00
#             min    1.756806e-01  4.527266e-01  4.941866e-01
#             25%    1.756806e-01  4.527266e-01  4.941866e-01
#             50%    1.756806e-01  4.527266e-01  4.941866e-01
#             75%    1.756806e-01  4.527266e-01  4.941866e-01
#             max    1.756806e-01  4.527266e-01  4.941866e-01

# %% [markdown]
# ### Min, Max, average & total non-normalized metrics for each cluster

# %%
# Top 10 customers that utilize social media application

new.sort_values(by='Social media total volume (Bytes)', ascending=False)[['customer ID','Social media total volume (Bytes)']].head(10)
# Out:
#          customer ID  Social media total volume (Bytes)
# 24759   2.082010e+14                          6081804.0
# 65563   2.082017e+14                          6081604.0
# 101614  2.082021e+14                          6081388.0
# 98129   2.082019e+14                          6081379.0
# 32721   2.082014e+14                          6081303.0
# 16093   2.082010e+14                          6081274.0
# 32117   2.082014e+14                          6081242.0
# 50541   2.082015e+14                          6080979.0
# 59707   2.082017e+14                          6080417.0
# 23154   2.082010e+14                          6080396.0

# %%
# Top 10 Customers using Netflix application
new.sort_values(by='Netflix total volume (Bytes)', ascending=False)[['customer ID','Netflix total volume (Bytes)']].head(10)
# Out:
#          customer ID  Netflix total volume (Bytes)
# 73773   2.082017e+14                    71036614.0
# 95954   2.082019e+14                    71034285.0
# 46707   2.082015e+14                    71027389.0
# 68015   2.082017e+14                    71027295.0
# 66562   2.082017e+14                    71024101.0
# 41995   2.082014e+14                    71022203.0
# 104890  2.082099e+14                    71020552.0
# 883     2.082003e+14                    71017543.0
# 64116   2.082017e+14                    71016188.0
# 83231   2.082018e+14                    71008672.0

# %%
# Top 10 customers using Google application
new.sort_values(by='Google total volume (Bytes)', ascending=False)[['customer ID','Google total volume (Bytes)']].head(10)
# Out:
#          customer ID  Google total volume (Bytes)
# 95156   2.082019e+14                   24775247.0
# 30557   2.082014e+14                   24775169.0
# 101762  2.082022e+14                   24772983.0
# 7312    2.082009e+14                   24770765.0
# 29788   2.082014e+14                   24770000.0
# 44260   2.082014e+14                   24768001.0
# 49991   2.082015e+14                   24767984.0
# 31662   2.082014e+14                   24767522.0
# 4688    2.082003e+14                   24767119.0
# 60441   2.082017e+14                   24765020.0

# %%
# Top 10 Customers that using youtube application
new.sort_values(by='Youtube total volume (Bytes)', ascending=False)[['customer ID','Youtube total volume (Bytes)']].head(10)
# Out:
#          customer ID  Youtube total volume (Bytes)
# 92720   2.082019e+14                    70951721.0
# 90452   2.082019e+14                    70947519.0
# 43760   2.082014e+14                    70946307.0
# 78052   2.082018e+14                    70946245.0
# 74925   2.082017e+14                    70946119.0
# 78504   2.082018e+14                    70940462.0
# 104566  2.082098e+14                    70938783.0
# 78923   2.082018e+14                    70935725.0
# 10072   2.082009e+14                    70933925.0
# 78709   2.082018e+14                    70932737.0

# %%
# Top 10 Customers that utilize Email application
new.sort_values(by='Email total volume (Bytes)',
                ascending=False)[['customer ID','Email total volume (Bytes)']].head(10)
# Out:
#         customer ID  Email total volume (Bytes)
# 3214   2.082003e+14                   7219422.0
# 71405  2.082017e+14                   7219153.0
# 70785  2.082017e+14                   7219112.0
# 43694  2.082014e+14                   7218782.0
# 51433  2.082015e+14                   7218696.0
# 38540  2.082014e+14                   7218034.0
# 99778  2.082021e+14                   7218008.0
# 21194  2.082010e+14                   7217750.0
# 39794  2.082014e+14                   7217596.0
# 63705  2.082017e+14                   7216619.0

# %%
# Top 10 Customers that utilize Gaming application
new.sort_values(by='Gaming total volume (Bytes)', ascending=False)[['customer ID','Gaming total volume (Bytes)']].head(10)
# Out:
#         customer ID  Gaming total volume (Bytes)
# 97165  2.082019e+14                 1.433029e+09
# 30794  2.082014e+14                 1.432997e+09
# 80823  2.082018e+14                 1.432967e+09
# 11271  2.082009e+14                 1.432962e+09
# 70841  2.082017e+14                 1.432707e+09
# 68130  2.082017e+14                 1.432456e+09
# 73356  2.082017e+14                 1.432357e+09
# 17053  2.082010e+14                 1.432320e+09
# 98880  2.082021e+14                 1.432259e+09
# 62508  2.082017e+14                 1.432075e+09

# %%
# Top 10 Customers that utilize Other source application
new.sort_values(by='Other source total volume (Bytes)', ascending=False)[['customer ID','Other source total volume (Bytes)']].head(10)
# Out:
#         customer ID  Other source total volume (Bytes)
# 6291   2.082003e+14                       2.828779e+09
# 42059  2.082014e+14                       2.828732e+09
# 2792   2.082003e+14                       2.828660e+09
# 72016  2.082017e+14                       2.828537e+09
# 98777  2.082021e+14                       2.828232e+09
# 76068  2.082017e+14                       2.828211e+09
# 19447  2.082010e+14                       2.828125e+09
# 14105  2.082010e+14                       2.827574e+09
# 95320  2.082019e+14                       2.827433e+09
# 87141  2.082019e+14                       2.827420e+09

# %%
#Determing the 3 most used application
labels = ['Social media', 'Google', 'Email','Youtube','Netflix','Gaming']
sizes = [new['Social media total volume (Bytes)'].sum(),
         new['Google total volume (Bytes)'].sum(),
         new['Email total volume (Bytes)'].sum(),
         new['Youtube total volume (Bytes)'].sum(),
         new['Netflix total volume (Bytes)'].sum(),
         new['Gaming total volume (Bytes)'].sum(),
        ]
# print(sizes) # adds up to 1433, which is the total number of participants
fig1, ax1 = plt.subplots(figsize = (6, 6))
colors = ['red', 'blue', 'green', 'yellow', 'orange', 'purple']
ax1.pie(sizes, labels=labels, autopct='%1.0f%%', colors=colors)

ax1.axis('equal')
plt.title("Total traffics per application")
plt.show()

# %%
#plot a chart for the top 3 used application
labels=['Netfilx','Youtube','Gaming']

sizes.sort()
top3 = sizes[3:]
ys=top3
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
plt.title("Top 3 used application", color='brown')
ax.bar(labels,ys)
plt.show()
